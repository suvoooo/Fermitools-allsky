# %% [markdown]
# ##### Check Python installation

# %%
# !which python
# Out:
# /usr/local/bin/python

# %%
# !echo $PYTHONPATH
# Out:
# /env/python

# %% [markdown]
# #### Properly install Anaconda (Check Version)
#
# Also it is possible to update conda after installation.

# %%
# !wget -c https://repo.anaconda.com/miniconda/Miniconda3-4.5.4-Linux-x86_64.sh
# !chmod +x Miniconda3-4.5.4-Linux-x86_64.sh
# !bash ./Miniconda3-4.5.4-Linux-x86_64.sh -b -f -p /usr/local
# Out:
# wget: /usr/local/lib/libuuid.so.1: no version information available (required by wget)
# --2020-09-17 09:20:34--  https://repo.anaconda.com/miniconda/Miniconda3-4.5.4-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 416 Requested Range Not Satisfiable
#
#     The file is already fully retrieved; nothing to do.
#
# PREFIX=/usr/local
# installing: python-3.6.5-hc3d631a_2 ...
# Python 3.6.5 :: Anaconda, Inc.
# installing: ca-certificates-2018.03.07-0 ...
# installing: conda-env-2.6.0-h36134e3_1 ...
# installing: libgcc-ng-7.2.0-hdf63c60_3 ...
# installing: libstdcxx-ng-7.2.0-hdf63c60_3 ...
# installing: libffi-3.2.1-hd88cf55_4 ...
# installing: ncurses-6.1-hf484d3e_0 ...
# installing: openssl-1.0.2o-h20670df_0 ...
# installing: tk-8.6.7-hc745277_3 ...
# ...

# %% [markdown]
# #### Check Conda Installation Path
#
# Also the version

# %%
# !which conda
# Out:
# /usr/local/bin/conda

# %%
# !conda --version
# Out:
# conda 4.5.4

# %% [markdown]
# Conda if properly installed should not damage the initial python path. So check again.

# %%
# !which python
# Out:
# /usr/local/bin/python

# %% [markdown]
# But this python is actually running from Anaconda Environment.

# %%
# !python --version
# Out:
# Python 3.6.5 :: Anaconda, Inc.

# %% [markdown]
# #### Install Ctools
#
# Copied the code form [here](https://anaconda.org/cta-observatory/ctools). Just for confirmation added the path for installation in prefix.

# %%
# !conda install -c cta-observatory ctools --prefix /usr/local
# Out:
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - ctools
#
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2018.03.07-0         --> 2020.7.22-0
#     certifi:         2018.4.16-py36_0     --> 2020.6.20-py36_0
#     conda:           4.5.4-py36_0         --> 4.8.4-py36_0
#     cryptography:    2.2.2-py36h14c3975_0 --> 3.1-py36h1ba5d50_0
#     libgcc-ng:       7.2.0-hdf63c60_3     --> 9.1.0-hdf63c60_0
#     libstdcxx-ng:    7.2.0-hdf63c60_3     --> 9.1.0-hdf63c60_0
#     openssl:         1.0.2o-h20670df_0    --> 1.1.1g-h7b6447c_0
#     python:          3.6.5-hc3d631a_2     --> 3.6.8-h0371630_0
#     sqlite:          3.23.1-he433501_0    --> 3.26.0-h7b6447c_0
#     tk:              8.6.7-hc745277_3     --> 8.6.10-hbc83047_0
#
# Proceed ([y]/n)? yes
#
# done
# done
# done

# %% [markdown]
# Check the current list of directories under python.

# %%
import sys 
sys.path
# Out:
# ['',
#  '/env/python',
#  '/usr/lib/python36.zip',
#  '/usr/lib/python3.6',
#  '/usr/lib/python3.6/lib-dynload',
#  '/usr/local/lib/python3.6/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.6/dist-packages/IPython/extensions',
#  '/root/.ipython']

# %% [markdown]
# But conda install packages under `/usr/local/lib/python3.6/site-packages`. So let's append this path.

# %%
_ = (sys.path
        .append("/usr/local/lib/python3.6/site-packages"))

# %% [markdown]
# If you try import ctools here it gives you error with libcfitsio.
#
# `ImportError: libcfitsio.so.5: cannot open shared object file: No such file or directory`.
# So let's see the installed libcfitsio
# below you will see libcfitsio.so.5 but that's after installing libcfitsio.

# %%
# !find / -name libcfitsio.*
# Out:
# /usr/lib/x86_64-linux-gnu/libcfitsio.so.5
# /usr/lib/x86_64-linux-gnu/libcfitsio.so.5.3.43
# /usr/local/lib/libcfitsio.so.8.3.47
# /usr/local/lib/libcfitsio.so
# /usr/local/lib/libcfitsio.a
# /usr/local/lib/libcfitsio.so.8
# /usr/local/pkgs/cfitsio-3.470-hb7c8383_2/lib/libcfitsio.so.8.3.47
# /usr/local/pkgs/cfitsio-3.470-hb7c8383_2/lib/libcfitsio.so
# /usr/local/pkgs/cfitsio-3.470-hb7c8383_2/lib/libcfitsio.a
# /usr/local/pkgs/cfitsio-3.470-hb7c8383_2/lib/libcfitsio.so.8
# /usr/local/pkgs/cfitsio-3.470-hf0d0db6_5/lib/libcfitsio.so.8.3.47
# /usr/local/pkgs/cfitsio-3.470-hf0d0db6_5/lib/libcfitsio.so
# /usr/local/pkgs/cfitsio-3.470-hf0d0db6_5/lib/libcfitsio.a
# /usr/local/pkgs/cfitsio-3.470-hf0d0db6_5/lib/libcfitsio.so.8
# /content/cfitsio-3.47/libcfitsio.so.8.3.47
# /content/cfitsio-3.47/libcfitsio.so
# /content/cfitsio-3.47/lib/libcfitsio.so.8.3.47
# /content/cfitsio-3.47/lib/libcfitsio.so
# /content/cfitsio-3.47/lib/libcfitsio.a
# /content/cfitsio-3.47/lib/libcfitsio.so.8
# ...

# %%
import ctools
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-21-82576f87306b> in <module>()
# ----> 1 import ctools
#
# /usr/local/lib/python3.6/site-packages/ctools/__init__.py in <module>()
#      19 # ==========================================================================
#      20 # import gammalib first
# ---> 21 import gammalib
#      22
#      23 # Import sub modules
#
# /usr/local/lib/python3.6/site-packages/gammalib/__init__.py in <module>()
#      19 # ==========================================================================
#      20 # Import modules
# ---> 21 from gammalib.app import *
#      22 from gammalib.base import *
#      23 from gammalib.fits import *
#
# /usr/local/lib/python3.6/site-packages/gammalib/app.py in <module>()
#      26                 fp.close()
#      27             return _mod
# ---> 28     _app = swig_import_helper()
# ...

# %% [markdown]
# Let's install the missing version of libcfitsio library

# %%
! apt-get install libcfitsio5
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libcfitsio5 is already the newest version (3.430-2).
# 0 upgraded, 0 newly installed, 0 to remove and 11 not upgraded.

# %% [markdown]
# Check again for sanity that now we indeed have libcfitsio.so.5

# %%
# !find / -name libcfitsio.*
# Out:
# /usr/lib/x86_64-linux-gnu/libcfitsio.so.5
# /usr/lib/x86_64-linux-gnu/libcfitsio.so.5.3.43
# /usr/local/lib/libcfitsio.so.8.3.47
# /usr/local/lib/libcfitsio.so
# /usr/local/lib/libcfitsio.a
# /usr/local/lib/libcfitsio.so.8
# /usr/local/pkgs/cfitsio-3.470-hb7c8383_2/lib/libcfitsio.so.8.3.47
# /usr/local/pkgs/cfitsio-3.470-hb7c8383_2/lib/libcfitsio.so
# /usr/local/pkgs/cfitsio-3.470-hb7c8383_2/lib/libcfitsio.a
# /usr/local/pkgs/cfitsio-3.470-hb7c8383_2/lib/libcfitsio.so.8
# /usr/local/pkgs/cfitsio-3.470-hf0d0db6_5/lib/libcfitsio.so.8.3.47
# /usr/local/pkgs/cfitsio-3.470-hf0d0db6_5/lib/libcfitsio.so
# /usr/local/pkgs/cfitsio-3.470-hf0d0db6_5/lib/libcfitsio.a
# /usr/local/pkgs/cfitsio-3.470-hf0d0db6_5/lib/libcfitsio.so.8
# /content/cfitsio-3.47/libcfitsio.so.8.3.47
# /content/cfitsio-3.47/libcfitsio.so
# /content/cfitsio-3.47/lib/libcfitsio.so.8.3.47
# /content/cfitsio-3.47/lib/libcfitsio.so
# /content/cfitsio-3.47/lib/libcfitsio.a
# /content/cfitsio-3.47/lib/libcfitsio.so.8
# ...

# %%
import ctools

# %%
# check 
sim = ctools.ctobssim()

print ("what's sim: ", type(sim))
# Out:
# what's sim:  <class 'ctools.tools.ctobssim'>
